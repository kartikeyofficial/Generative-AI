# %% [markdown]
# ## File Path

# %%
## Create a New Directory
import os
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'package' created

# %%
## Listing Files and Directories
import os


items = os.listdir('.')
print(items)
# Out:
# ['example.txt', 'example.bin', 'filePath.ipynb', 'fileoperation.ipynb']

# %%
## Joining Paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
path = 'example.bin'
if os.path.exists(path):
    print(f"'{path}' exists.")
else:
    print(f"'{path}' does not exist.")
# Out:
# 'example.bin' exists.
